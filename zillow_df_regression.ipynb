# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a reference the CSV file desired
#using last csv sent by Ariel on Slack
csv_path ="Resources/house_values_neighbor_reg.csv"

#Read the csv
incident_report = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
incident_report.head(50)
# Out:
#                       Neighborhood       2018-01       2018-02       2018-03  \
# 0            Bayview Hunters Point  8.313694e+05  8.368342e+05  8.423898e+05
# 1                   Bernal Heights  1.375103e+06  1.387180e+06  1.399212e+06
# 2             Castro /Upper Market  1.654890e+06  1.665722e+06  1.674729e+06
# 3                       Chinatown   9.320361e+05  9.371647e+05  9.422865e+05
# 4                        Excelsior  9.719333e+05  9.802134e+05  9.877608e+05
# 5   Financial District/South Beach  1.075950e+06  1.078618e+06  1.081246e+06
# 6                        Glen Park  1.405747e+06  1.421693e+06  1.435651e+06
# 7                   Haight Ashbury  1.539832e+06  1.546508e+06  1.551878e+06
# 8                     Hayes Valley  1.138367e+06  1.147311e+06  1.153989e+06
# 9                   Inner Richmond  1.948172e+06  1.968511e+06  1.981079e+06
# 10                    Inner Sunset  1.516317e+06  1.532675e+06  1.546822e+06
# ...

# %%
#Getting the name of the columns to turn them into rows
incident_report.columns
# Out:
# Index(['Neighborhood', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05',
#        '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11',
#        '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05',
#        '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11',
#        '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05',
#        '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11',
#        '2020-12', '2021-01', '2021-02', '2021-03', '2021-04', '2021-05',
#        '2021-06', '2021-07', '2021-08', '2021-09', '2021-10', '2021-11',
#        '2021-12', '2022-01', '2022-02', '2022-03', '2022-04', '2022-05',
#        '2022-06', '2022-07', '2022-08', '2022-09', '2022-10', '2022-11',
#        '2022-12'],
#       dtype='object')

# %%
#Turning the columns into rows.
df_melted = pd.melt(incident_report, id_vars=['Neighborhood'], value_vars=['2018-01', '2018-02', '2018-03', '2018-04', '2018-05',
       '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11',
       '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05',
       '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11',
       '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05',
       '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11',
       '2020-12', '2021-01', '2021-02', '2021-03', '2021-04', '2021-05',
       '2021-06', '2021-07', '2021-08', '2021-09', '2021-10', '2021-11',
       '2021-12', '2022-01', '2022-02', '2022-03', '2022-04', '2022-05',
       '2022-06', '2022-07', '2022-08', '2022-09', '2022-10', '2022-11',
       '2022-12'], var_name='Date', value_name='Price')

# %%
display(df_melted)
# Out:
#                Neighborhood     Date         Price
# 0     Bayview Hunters Point  2018-01  8.313694e+05
# 1            Bernal Heights  2018-01  1.375103e+06
# 2      Castro /Upper Market  2018-01  1.654890e+06
# 3                Chinatown   2018-01  9.320361e+05
# 4                 Excelsior  2018-01  9.719333e+05
# ...                     ...      ...           ...
# 2215             Tenderloin  2022-12  7.817490e+05
# 2216             Twin Peaks  2022-12  1.472301e+06
# 2217      Visitacion Valley  2022-12  9.111010e+05
# 2218     West of Twin Peaks  2022-12  1.963557e+06
# 2219       Western Addition  2022-12  1.037988e+06
#
# [2220 rows x 3 columns]

# %%
#Getting the price by neighborhood and date. Numbers for Bayview Hunters Point on 01/2018 matches with the prior table.
gruopbymelted = df_melted.groupby(["Neighborhood","Date"]).sum()
gruopbymelted
# Out:
#                                       Price
# Neighborhood          Date
# Bayview Hunters Point 2018-01  8.313694e+05
#                       2018-02  8.368342e+05
#                       2018-03  8.423898e+05
#                       2018-04  8.467867e+05
#                       2018-05  8.547810e+05
# ...                                     ...
# Western Addition      2022-08  1.105756e+06
#                       2022-09  1.082914e+06
#                       2022-10  1.064080e+06
#                       2022-11  1.049605e+06
#                       2022-12  1.037988e+06
#
# [2220 rows x 1 columns]

# %%
#Getting the final DataFrame to performn the regression. 
zillow_regression = pd.DataFrame(gruopbymelted)

# %%
#Save the file as a csv.
zillow_regression.to_csv("zillow_regression.csv")
