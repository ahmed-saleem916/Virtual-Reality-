# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
house_file = "../Resources/house_values_neighbor_reg.csv"
crime_file ="../Resources/incident_sum_neighbor_reg.csv"

house_df = pd.read_csv(house_file)
crime_df = pd.read_csv(crime_file)

# %%
crime_df
# Out:
#                       Neighborhood  2018-01  2018-02  2018-03  2018-04  \
# 0            Bayview Hunters Point      476      397      420      460
# 1                   Bernal Heights      163      111      127      137
# 2              Castro/Upper Market      210      165      230      214
# 3                        Chinatown      196      176      127      151
# 4                        Excelsior      162      166      154      130
# 5   Financial District/South Beach      699      642      651      726
# 6                        Glen Park       33       30       32       51
# 7                 Golden Gate Park       88       57       54       59
# 8                   Haight Ashbury      108      110       95      108
# 9                     Hayes Valley      194      122      131      179
# 10                  Inner Richmond       99       98       93      115
# 11                    Inner Sunset       95       83       91       82
# ...

# %%
house_df
# Out:
#                       Neighborhood       2018-01       2018-02       2018-03  \
# 0            Bayview Hunters Point  8.313694e+05  8.368342e+05  8.423898e+05
# 1                   Bernal Heights  1.375103e+06  1.387180e+06  1.399212e+06
# 2             Castro /Upper Market  1.654890e+06  1.665722e+06  1.674729e+06
# 3                       Chinatown   9.320361e+05  9.371647e+05  9.422865e+05
# 4                        Excelsior  9.719333e+05  9.802134e+05  9.877608e+05
# 5   Financial District/South Beach  1.075950e+06  1.078618e+06  1.081246e+06
# 6                        Glen Park  1.405747e+06  1.421693e+06  1.435651e+06
# 7                   Haight Ashbury  1.539832e+06  1.546508e+06  1.551878e+06
# 8                     Hayes Valley  1.138367e+06  1.147311e+06  1.153989e+06
# 9                   Inner Richmond  1.948172e+06  1.968511e+06  1.981079e+06
# 10                    Inner Sunset  1.516317e+06  1.532675e+06  1.546822e+06
# ...
