# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
# added later for linregress
from scipy.stats import linregress

# %%
file = "../Resources/crime_rate_per_neighborhood.csv"

file_violent = "../Resources/violent_crimes_price_rate.csv"
file_nonviolent = "../Resources/nonviolent_crimes_price_rate.csv"

crime_rate = pd.read_csv(file)
violent_crime = pd.read_csv(file_violent)
nonviolent_crime = pd.read_csv(file_nonviolent)

# %%
crime_rate
# Out:
#       Unnamed: 0           Neighborhood     Date         Price  \
# 0              0  Bayview Hunters Point  2018-01  8.313694e+05
# 1              1  Bayview Hunters Point  2018-02  8.368342e+05
# 2              2  Bayview Hunters Point  2018-03  8.423898e+05
# 3              3  Bayview Hunters Point  2018-04  8.467867e+05
# 4              4  Bayview Hunters Point  2018-05  8.547810e+05
# ...          ...                    ...      ...           ...
# 2035        2035       Western Addition  2022-08  1.105756e+06
# 2036        2036       Western Addition  2022-09  1.082914e+06
# 2037        2037       Western Addition  2022-10  1.064080e+06
# 2038        2038       Western Addition  2022-11  1.049605e+06
# 2039        2039       Western Addition  2022-12  1.037988e+06
#
#       Number of Crimes  Year  Population  Crime Rate
# 0                  751  2018     38480.0    0.019517
# 1                  653  2018     38480.0    0.016970
# ...

# %%
x_values = crime_rate["Crime Rate"]
y_values = crime_rate["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("SF Incidents and House Value")
plt.show()

# %%
violent_crime
# Out:
#          Date           Neighborhood         Price  Crime Rate
# 0     2018-01  Bayview Hunters Point  8.313694e+05   39.760915
# 1     2018-02  Bayview Hunters Point  8.368342e+05   26.767152
# 2     2018-03  Bayview Hunters Point  8.423898e+05   37.422037
# 3     2018-04  Bayview Hunters Point  8.467867e+05   34.823285
# 4     2018-05  Bayview Hunters Point  8.547810e+05   30.665281
# ...       ...                    ...           ...         ...
# 2019  2022-08       Western Addition  1.105756e+06   28.700839
# 2020  2022-09       Western Addition  1.082914e+06   26.458586
# 2021  2022-10       Western Addition  1.064080e+06   29.149289
# 2022  2022-11       Western Addition  1.049605e+06   23.319431
# 2023  2022-12       Western Addition  1.037988e+06   23.319431
#
# [2024 rows x 4 columns]

# %%
x_values = violent_crime["Crime Rate"]
y_values = violent_crime["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("SF Violent Crime and House Value")
plt.show()

# %%
x_values = nonviolent_crime["Crime Rate"]
y_values = nonviolent_crime["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("SF Non-Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.10120794715100614

# %%
presidio = violent_crime.loc[violent_crime["Neighborhood"] == "Presidio"]
nonviolent_presidio = nonviolent_crime.loc[nonviolent_crime["Neighborhood"] == "Presidio"]

# %%
# Presidio Violent Regression
x_values = presidio["Crime Rate"]
y_values = presidio["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Presidio Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.005141574955380437

# %%
# Presidio Non-Violent Regression
x_values = nonviolent_presidio["Crime Rate"]
y_values = nonviolent_presidio["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Presidio Non-Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.007059977396279838

# %%
tenderloin = violent_crime.loc[violent_crime["Neighborhood"] == "Tenderloin"]
nonviolent_tenderloin = nonviolent_crime.loc[nonviolent_crime["Neighborhood"] == "Tenderloin"]

# %%
# Tenderloin Violent Regression
x_values = tenderloin["Crime Rate"]
y_values = tenderloin["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Tenderloin Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.06963908579036171

# %%
# Tenderloin Non-Violent Regression
x_values = nonviolent_tenderloin["Crime Rate"]
y_values = nonviolent_tenderloin["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Tenderloin Non-Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.060425535290570355

# %%
financial = violent_crime.loc[violent_crime["Neighborhood"] == "Financial District/South Beach"]
nonviolent_financial = nonviolent_crime.loc[nonviolent_crime["Neighborhood"] == "Financial District/South Beach"]

# %%
# Financial District Violent Regression
x_values = financial["Crime Rate"]
y_values = financial["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Financial District/South Beach Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.018389050552708158

# %%
# Financial District Non-Violent Regression
x_values = nonviolent_financial["Crime Rate"]
y_values = nonviolent_financial["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Financial District/South Beach Non-Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.15578629177623546

# %%
presidio_heights = violent_crime.loc[violent_crime["Neighborhood"] == "Presidio Heights"]
nonviolent_heights = nonviolent_crime.loc[nonviolent_crime["Neighborhood"] == "Presidio Heights"]

# %%
# Presidio Heights Violent Regression
x_values = presidio_heights["Crime Rate"]
y_values = presidio_heights["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Presidio Heights Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0012865652477379455

# %%
# Presidio Heights Non-Violent Regression
x_values = nonviolent_heights["Crime Rate"]
y_values = nonviolent_heights["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Presidio Heights Non-Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.016993678394821365

# %%
mission = violent_crime.loc[violent_crime["Neighborhood"] == "Mission"]
nonviolent_mission = nonviolent_crime.loc[nonviolent_crime["Neighborhood"] == "Mission"]

# %%
# Mission Violent Regression
x_values = mission["Crime Rate"]
y_values = mission["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Mission Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.05465463723220243

# %%
# Mission Non-Violent Regression
x_values = nonviolent_mission["Crime Rate"]
y_values = nonviolent_mission["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Mission Non-Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00037033786136184653

# %%
seacliff = violent_crime.loc[violent_crime["Neighborhood"] == "Seacliff"]
nonviolent_seacliff = nonviolent_crime.loc[nonviolent_crime["Neighborhood"] == "Seacliff"]

# %%
# Seacliff Violent Regression
x_values = seacliff["Crime Rate"]
y_values = seacliff["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Seacliff Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00034427166651198763

# %%
# Seacliff Non-Violent Regression
x_values = nonviolent_seacliff["Crime Rate"]
y_values = nonviolent_seacliff["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Seacliff Non-Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.06465440422305889

# %%
bayview = violent_crime.loc[violent_crime["Neighborhood"] == "Bayview Hunters Point"]
nonviolent_bayview = nonviolent_crime.loc[nonviolent_crime["Neighborhood"] == "Bayview Hunters Point"]

# %%
# Bayview Hunters Point Violent Regression
x_values = bayview["Crime Rate"]
y_values = bayview["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Bayview Hunters Point Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.023826071772067723

# %%
# Bayview Hunters Point Non-Violent Regression
x_values = nonviolent_bayview["Crime Rate"]
y_values = nonviolent_bayview["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Bayview Hunters Point Non-Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.11518677490005427

# %%
glen_park = violent_crime.loc[violent_crime["Neighborhood"] == "Glen Park"]
nonviolent_glen_park = nonviolent_crime.loc[nonviolent_crime["Neighborhood"] == "Glen Park"]

# %%
# Glen Park Violent Regression
x_values = glen_park["Crime Rate"]
y_values = glen_park["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Glen Park Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.006703744648769658

# %%
# Glen Park Non-Violent Regression
x_values = nonviolent_glen_park["Crime Rate"]
y_values = nonviolent_glen_park["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Glen Park Non-Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.1428270326908337

# %%
south_market = violent_crime.loc[violent_crime["Neighborhood"] == "South of Market"]
nonviolent_south = nonviolent_crime.loc[nonviolent_crime["Neighborhood"] == "South of Market"]

# %%
# South of Market Violent Regression
x_values = south_market["Crime Rate"]
y_values = south_market["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("South of Market Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.005291699205354655

# %%
# South of Market Non-Violent Regression
x_values = nonviolent_south["Crime Rate"]
y_values = nonviolent_south["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("South of Market Non-Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.06784288872844539

# %%
twin_peaks = violent_crime.loc[violent_crime["Neighborhood"] == "Twin Peaks"]
nonviolent_twin = nonviolent_crime.loc[nonviolent_crime["Neighborhood"] == "Twin Peaks"]

# %%
# Twin Peaks Violent Regression
x_values = twin_peaks["Crime Rate"]
y_values = twin_peaks["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Twin Peaks Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.003191885406149707

# %%
# Twin Peaks Non-Violent Regression
x_values = nonviolent_twin["Crime Rate"]
y_values = nonviolent_twin["Price"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.ylabel("House Value")
plt.xlabel("Crime Rate")
plt.title("Twin Peaks Non-Violent Crime and House Value")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.007938715936479615
