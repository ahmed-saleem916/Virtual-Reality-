# %%
import pandas as pd
import requests
import lxml
import html5lib
#from bs4 import beautifulsoup4
#https://developers.tiktok.com/doc/research-api-specs-query-videos/
#https://data.cityofnewyork.us/Public-Safety/NYPD-Arrest-Data-Year-to-Date-/uip8-fykc
# Library for opening url and creating 
# requests
import urllib.request

# pretty-print python data structures
from pprint import pprint

# for parsing all the tables present 
# on the website
from html_table_parser.parser import HTMLTableParser

# %%
csv_zillow_median_housing_sale = pd.read_csv("Metro_median_sale_price_uc_sfrcondo_sm_month.csv")
csv_crime_data = pd.read_csv("Police_Department_Incident_Reports__2018_to_Present.csv")
csv_sf_housing = pd.read_csv("City_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")

# %%
df_medhousing = pd.DataFrame(csv_zillow_median_housing_sale)
df_police = pd.DataFrame(csv_crime_data)
df_sfhousing = pd.DataFrame(csv_sf_housing)

# %%
df_ca_zillow = df_medhousing.loc[df_medhousing["RegionName"] == "San Francisco, CA"]
df_ca_zillow
# Out:
#     RegionID  SizeRank         RegionName RegionType StateName  2008-04-30  \
# 12    395057        12  San Francisco, CA        msa        CA    575333.0
#
#     2008-05-31  2008-06-30  2008-07-31  2008-08-31  ...  2022-04-30  \
# 12    572667.0    562500.0    550833.0    525833.0  ...   1152500.0
#
#     2022-05-31  2022-06-30  2022-07-31  2022-08-31  2022-09-30  2022-10-31  \
# 12   1215000.0   1233333.0   1186667.0   1111667.0   1064917.0   1054917.0
#
#     2022-11-30  2022-12-31  2023-01-31
# 12   1063250.0   1026000.0    967667.0
#
# [1 rows x 183 columns]

# %%
df_ca_housing = df_sfhousing.loc[df_sfhousing["State"] == "CA"]
df_sf = df_ca_housing.loc[df_ca_housing["RegionName"] == "San Francisco"]
df_sf
# Out:
#     RegionID  SizeRank     RegionName RegionType StateName State  \
# 14     20330        14  San Francisco       city        CA    CA
#
#                                  Metro            CountyName    2018/1/31  \
# 14  San Francisco-Oakland-Berkeley, CA  San Francisco County  1172500.617
#
#       2018/2/28  ...    2022/5/31    2022/6/30    2022/7/31    2022/8/31  \
# 14  1183457.237  ...  1419670.029  1411703.615  1392442.441  1363056.012
#
#     2022/9/30   2022/10/31   2022/11/30   2022/12/31    2023/1/31   2023/2/28
# 14  1329771.8  1301258.631  1278285.715  1258868.535  1246810.122  1238020.58
#
# [1 rows x 70 columns]

# %%
df_police_columns = df_police[["Incident Date", "Latitude", "Longitude", "Incident Description", "Incident Category", "Incident Subcategory"]]
df_police_columns_no_na = df_police_columns.dropna()
df_police_columns_no_na.to_csv("sf_police_data_cleaned.csv")
df_police_columns_no_na.groupby("Incident Category").count()
# Out:
#                                               Incident Date  Latitude  \
# Incident Category
# Arson                                                  2020      2020
# Assault                                               42853     42853
# Burglary                                              39331     39331
# Case Closure                                           2819      2819
# Civil Sidewalks                                         886       886
# Courtesy Report                                        2013      2013
# Suicide                                             315                   315
# Suspicious                                          101                   101
# Suspicious Occ                                    14452                 14452
# Traffic Collision                                  1626                  1626
# Traffic Violation Arrest                           6778                  6778
# Vandalism                                          1501                  1501
# Vehicle Impounded                                   440                   440
# Vehicle Misplaced                                   284                   284
# Warrant                                           20230                 20230
# Weapons Carrying Etc                               3854                  3854
# Weapons Offence                                      21                    21
# Weapons Offense                                    4798                  4798
#
#                                               Incident Subcategory
# Incident Category
# Arson                                                         2020
# Assault                                                      42853
# Burglary                                                     39331
# Case Closure                                                  2819
# Civil Sidewalks                                                886
# Courtesy Report                                               2013
# Disorderly Conduct                                           11576
# Drug Offense                                                 17118
# Drug Violation                                                 237
# Embezzlement                                                   906
# Fire Report                                                   1028
# Forgery And Counterfeiting                                    2398
# Fraud                                                        22110
# Gambling                                                        32
# Homicide                                                       102
# Human Trafficking (A), Commercial Sex Acts                     130
# Human Trafficking (B), Involuntary Servitude                     1
# Human Trafficking, Commercial Sex Acts                          21
# Larceny Theft                                               195439
# Liquor Laws                                                     76
# Lost Property                                                16547
# Malicious Mischief                                           45729
# Miscellaneous Investigation                                   7324
# Missing Person                                               15244
# Motor Vehicle Theft                                          35594
# Motor Vehicle Theft?                                            72
# Non-Criminal                                                 41392
# Offences Against The Family And Children                      9766
# Other                                                         5726
# Other Miscellaneous                                          49104
# Other Offenses                                                5122
# Prostitution                                                   925
# Rape                                                           171
# Recovered Vehicle                                            19926
# Robbery                                                      15677
# Sex Offense                                                    736
# Stolen Property                                               3495
# Suicide                                                        315
# Suspicious                                                     101
# Suspicious Occ                                               14452
# Traffic Collision                                             1626
# Traffic Violation Arrest                                      6778
# Vandalism                                                     1501
# Vehicle Impounded                                              440
# Vehicle Misplaced                                              284
# Warrant                                                      20230
# Weapons Carrying Etc                                          3854
# Weapons Offence                                                 21
# Weapons Offense                                               4798

# %%
df_police_data_crime = df_police_columns_no_na.loc[(df_police_columns_no_na["Incident Category"].str.contains("Arson")) | (df_police_columns_no_na["Incident Category"].str.contains("Assault")) | 
                                                   (df_police_columns_no_na["Incident Category"].str.contains("Burglary")) | (df_police_columns_no_na["Incident Category"].str.contains("Homicide")) |
                                                   (df_police_columns_no_na["Incident Category"].str.contains("Rape")) | (df_police_columns_no_na["Incident Category"].str.contains("Robbery"))
                                                   (df_police_columns_no_na["Incident Category"].str.contains("Sex Offense")) | (df_police_columns_no_na["Incident Category"].str.contains("Rape"))
                                                   (df_police_columns_no_na["Incident Category"].str.contains("Vandalism"))]

# %%
#url = "https://belonging.berkeley.edu/most-segregated-cities-bay-area-2020"
#Current redlining / segregation source: https://belonging.berkeley.edu/racial-segregation-san-francisco-bay-area-part-1
# Opens a website and read its
# binary contents (HTTP Response Body)
def url_get_contents(url):

    # Opens a website and read its
    # binary contents (HTTP Response Body)

    #making request to the website
    req = urllib.request.Request(url=url)
    f = urllib.request.urlopen(req)

    #reading contents of the website
    return f.read()

# defining the html contents of a URL.
xhtml = url_get_contents('https://belonging.berkeley.edu/most-segregated-cities-bay-area-2020').decode('utf-8')

# Defining the HTMLTableParser object
p = HTMLTableParser()

# feeding the html contents in the
# HTMLTableParser object
p.feed(xhtml)

# Now finally obtaining the data of
# the table required
#pprint(p.tables[1])

# %%
table0 = pd.DataFrame(p.tables[0]) #The 20 Most Segregated Cities in the Bay Area
table1 = pd.DataFrame(p.tables[1]) #Cities with the Highest Levels of Neighborhood Segregation in the Bay Area
table2 = pd.DataFrame(p.tables[2]) #The 10 Most Segregated Black Neighborhoods in the Bay Area
table3 = pd.DataFrame(p.tables[3]) #The 10 Most Segregated Latino Neighborhoods in the Bay Area
table4 = pd.DataFrame(p.tables[4]) #The 10 Most Segregated Asian Neighborhoods in the Bay Area
table5 = pd.DataFrame(p.tables[5]) #The Top 10 Most Segregated White Neighborhoods in the Bay Area
table6 = pd.DataFrame(p.tables[5]) #The Integrated Cities in the Bay Area

# %%
table6
# Out:
#                                      0            1           2          3  \
# 0                         Neighborhood    City/Town  Divergence  Asian (%)
# 1                                 Ross         Ross      0.6308      1.80%
# 2                            Belvedere    Belvedere      0.5736      3.30%
# 3                     Homestead Valley  Mill Valley      0.5466      3.60%
# 4            Kennedy Rd/Los Gatos Blvd    Los Gatos      0.5455     10.70%
# 5                      Lexington Hills    Los Gatos      0.5426      6.30%
# 6                          City Center  Mill Valley      0.5275      4.00%
# 7                             Woodacre     Woodacre      0.5175      1.80%
# 8                              Bolinas      Bolinas      0.5117      1.80%
# 9                        Sleepy Hallow  San Anselmo      0.5063      2.90%
# 10  Sir Francis Drake Blvd/Calumet Ave  San Anselmo      0.5019      2.30%
#
#             4           5                    6  \
# 0   Black (%)  Latino (%)  Native American (%)
# 1       0.10%       5.70%                0.00%
# 2       0.80%       5.20%                0.20%
# 3       0.40%       5.30%                0.10%
# 4       0.30%       5.80%                0.20%
# 5       0.70%      10.00%                0.30%
# 6       0.60%       5.50%                0.10%
# 7       0.80%       8.30%                0.40%
# 8       0.70%       9.00%                0.40%
# 9       0.50%       8.20%                0.10%
# 10      0.60%       8.70%                0.20%
#
#                                            7          8          9
# 0   Native Hawaiian and Pacific Islander (%)  White (%)  Other (%)
# 1                                      0.00%     87.40%      5.00%
# 2                                      0.00%     86.50%      4.00%
# 3                                      0.10%     84.00%      6.40%
# 4                                      0.00%     76.90%      6.10%
# 5                                      0.00%     75.10%      7.50%
# 6                                      0.00%     83.20%      6.50%
# 7                                      0.10%     80.70%      7.80%
# 8                                      0.30%     81.10%      6.50%
# 9                                      0.10%     81.50%      6.80%
# 10                                     0.10%     80.30%      7.80%
