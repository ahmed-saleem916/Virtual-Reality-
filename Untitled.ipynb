# %%
import pandas as pd


inventory_house_data= "zillow_data_project.csv"

house_data= pd.read_csv(inventory_house_data)

house_data
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2018-03-31  \
# 0      102001         0    United States    country       NaN   1421528.0
# 1      394913         1     New York, NY        msa        NY     73707.0
# 2      753899         2  Los Angeles, CA        msa        CA     21998.0
# 3      394463         3      Chicago, IL        msa        IL     38581.0
# 4      394514         4       Dallas, TX        msa        TX     24043.0
# ..        ...       ...              ...        ...       ...         ...
# 923    753929       923       Zapata, TX        msa        TX        55.0
# 924    394743       924    Ketchikan, AK        msa        AK        77.0
# 925    753874       925        Craig, CO        msa        CO       115.0
# 926    394767       926       Lamesa, TX        msa        TX        35.0
# 927    395188       927       Vernon, TX        msa        TX        21.0
#
#      2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2022-05-31  \
# ...
