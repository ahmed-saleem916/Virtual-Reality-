# %%
import pandas as pd


sales_count = "../SALES_COUNT_PRICECUTS.CSV"


sales_read = pd.read_csv(sales_count)



sales_read
# Out:
#     RegionID  SizeRank        RegionName RegionType StateName  2008-02-29  \
# 0     102001         0     United States    country       NaN    152730.0
# 1     394913         1      New York, NY        msa        NY      7431.0
# 2     753899         2   Los Angeles, CA        msa        CA      3262.0
# 3     394463         3       Chicago, IL        msa        IL      3869.0
# 4     394514         4        Dallas, TX        msa        TX      4494.0
# ..       ...       ...               ...        ...       ...         ...
# 89    394549        91        Durham, NC        msa        NC       336.0
# 90    395143        92      Syracuse, NY        msa        NY       355.0
# 91    395224        93       Wichita, KS        msa        KS        57.0
# 92    395160        94        Toledo, OH        msa        OH       172.0
# 93    394602       150  Fort Collins, CO        msa        CO       207.0
#
#     2008-03-31  2008-04-30  2008-05-31  2008-06-30  ...  2022-05-31  \
# ...

# %%
sales_data = sales_read.drop(sales_read.iloc[:,9:225], axis=1)
sf_data = sales_data[sales_data['RegionName'] == "San Francisco, CA"]

# %%
sf_data["RegionName"].nunique()
# Out:
# 1

# %%
sales_count = "../SALES_COUNT_PRICECUTS.CSV"

sales_data = pd.read_csv(sales_count)


sales_data
# Out:
#     RegionID  SizeRank        RegionName RegionType StateName  2008-02-29  \
# 0     102001         0     United States    country       NaN    152730.0
# 1     394913         1      New York, NY        msa        NY      7431.0
# 2     753899         2   Los Angeles, CA        msa        CA      3262.0
# 3     394463         3       Chicago, IL        msa        IL      3869.0
# 4     394514         4        Dallas, TX        msa        TX      4494.0
# ..       ...       ...               ...        ...       ...         ...
# 89    394549        91        Durham, NC        msa        NC       336.0
# 90    395143        92      Syracuse, NY        msa        NY       355.0
# 91    395224        93       Wichita, KS        msa        KS        57.0
# 92    395160        94        Toledo, OH        msa        OH       172.0
# 93    394602       150  Fort Collins, CO        msa        CO       207.0
#
#     2008-03-31  2008-04-30  2008-05-31  2008-06-30  ...  2022-05-31  \
# ...

# %%
column_name = list(sales_read.column.values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2052\3827539455.py in <module>
# ----> 1 column_name = list(sales_read.column.values)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'column'
